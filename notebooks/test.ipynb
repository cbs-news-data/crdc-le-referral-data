# %% [markdown]
# # Analysis of CRDC referral and arrest data

# %%
import re
import numpy as np
import pandas as pd

# %%
READ_ARGS = {"low_memory": False, "encoding": "latin"}

lower_cols = lambda col: col.lower()

enr = pd.read_csv("input/1718-crdc-sch-enrollment.csv", **READ_ARGS).rename(columns=lower_cols)
arr = pd.read_csv("input/1718-crdc-sch-referrals-arrests.csv", **READ_ARGS).rename(columns=lower_cols)
cha = pd.read_csv("input/1718-crdc-sch-characteristics.csv", **READ_ARGS).rename(columns=lower_cols)

# %% [markdown]
# ## Overall rates

# %%
MAX_GRADE = 5
JOIN_ARGS = {"how": "left"}
INDEX_COLS = [
    "combokey",
    "sch_name",
    "lea_name",
    "lea_state_name",
    "jj",
]

sum_sch = lambda df, kwd, colname: (
    df.set_index(INDEX_COLS)[[c for c in df if "tot_" in c and kwd in c]]
    .sum(axis=1)
    .to_frame(colname)
    .query(f"{colname} > 0")
)


def get_max_grade(row):
    true_cols = [
        (k, v) for k, v in row.iteritems() if k.startswith("sch_grade_g") and v == "Yes"
    ]
    if len(true_cols) == 0:
        return np.NaN
    return int(re.search(r"(?<=sch_grade_g)\d{1,2}$", true_cols[-1][0]).group())


cha = cha.set_index(INDEX_COLS + ["sch_status_alt"]).assign(
    max_grade=lambda df: df.apply(get_max_grade, axis=1)
)[["max_grade"]]


MULT = 10_000
assign_rates = lambda df: (
    df.assign(arrest_rate=lambda df: df.arrests / df.enrollment * MULT).assign(
        referral_rate=lambda df: df.referrals / df.enrollment * MULT
    )
)


tot_df = (
    sum_sch(enr, "enr", "enrollment")
    .join(cha, **JOIN_ARGS)
    .join(sum_sch(arr, "arr", "arrests"), **JOIN_ARGS)
    .join(sum_sch(arr, "ref", "referrals"), **JOIN_ARGS)
    .query(
        "max_grade <= @MAX_GRADE & index.get_level_values('jj') == 'No' & index.get_level_values('sch_status_alt') == 'No'"
    )
    .pipe(assign_rates)
)

tot_df.head()
# Out:
#                                                                                                     enrollment  \
# combokey     sch_name                            lea_name         lea_state_name jj sch_status_alt
# 010000500889 Albertville Elementary School       Albertville City ALABAMA        No No                    1565
# 010000502150 Albertville Primary School          Albertville City ALABAMA        No No                    1712
# 010000600876 Claysville School                   Marshall County  ALABAMA        No No                     237
# 010000600877 Douglas Elementary School           Marshall County  ALABAMA        No No                     723
# 010000600880 Brindlee Mountain Elementary School Marshall County  ALABAMA        No No                     257
#
#                                                                                                     max_grade  \
# combokey     sch_name                            lea_name         lea_state_name jj sch_status_alt
# 010000500889 Albertville Elementary School       Albertville City ALABAMA        No No                    4.0
# 010000502150 Albertville Primary School          Albertville City ALABAMA        No No                    2.0
# 010000600876 Claysville School                   Marshall County  ALABAMA        No No                    4.0
# 010000600877 Douglas Elementary School           Marshall County  ALABAMA        No No                    5.0
# 010000600880 Brindlee Mountain Elementary School Marshall County  ALABAMA        No No                    5.0
#
#                                                                                                     arrests  \
# combokey     sch_name                            lea_name         lea_state_name jj sch_status_alt
# 010000500889 Albertville Elementary School       Albertville City ALABAMA        No No                  NaN
# 010000502150 Albertville Primary School          Albertville City ALABAMA        No No                  NaN
# 010000600876 Claysville School                   Marshall County  ALABAMA        No No                  NaN
# 010000600877 Douglas Elementary School           Marshall County  ALABAMA        No No                  NaN
# 010000600880 Brindlee Mountain Elementary School Marshall County  ALABAMA        No No                  NaN
#
#                                                                                                     referrals  \
# combokey     sch_name                            lea_name         lea_state_name jj sch_status_alt
# 010000500889 Albertville Elementary School       Albertville City ALABAMA        No No                    NaN
# 010000502150 Albertville Primary School          Albertville City ALABAMA        No No                    NaN
# 010000600876 Claysville School                   Marshall County  ALABAMA        No No                    NaN
# 010000600877 Douglas Elementary School           Marshall County  ALABAMA        No No                    NaN
# 010000600880 Brindlee Mountain Elementary School Marshall County  ALABAMA        No No                    NaN
#
#                                                                                                     arrest_rate  \
# combokey     sch_name                            lea_name         lea_state_name jj sch_status_alt
# 010000500889 Albertville Elementary School       Albertville City ALABAMA        No No                      NaN
# 010000502150 Albertville Primary School          Albertville City ALABAMA        No No                      NaN
# 010000600876 Claysville School                   Marshall County  ALABAMA        No No                      NaN
# 010000600877 Douglas Elementary School           Marshall County  ALABAMA        No No                      NaN
# 010000600880 Brindlee Mountain Elementary School Marshall County  ALABAMA        No No                      NaN
#
#                                                                                                     referral_rate
# combokey     sch_name                            lea_name         lea_state_name jj sch_status_alt
# 010000500889 Albertville Elementary School       Albertville City ALABAMA        No No                        NaN
# 010000502150 Albertville Primary School          Albertville City ALABAMA        No No                        NaN
# 010000600876 Claysville School                   Marshall County  ALABAMA        No No                        NaN
# 010000600877 Douglas Elementary School           Marshall County  ALABAMA        No No                        NaN
# 010000600880 Brindlee Mountain Elementary School Marshall County  ALABAMA        No No                        NaN

# %% [markdown]
# ### National

# %%
national_rates = (
    tot_df[["enrollment", "referrals", "arrests"]]
    .sum()
    .to_frame("United States")
    .transpose()
    .pipe(assign_rates)
    .iloc[0]
)

national_rates
# Out:
# enrollment       2.438163e+07
# referrals        1.289200e+04
# arrests          2.607000e+03
# arrest_rate      1.069248e+00
# referral_rate    5.287588e+00
# Name: United States, dtype: float64

# %% [markdown]
# ### By state

# %%
(
    tot_df.reset_index()
    .groupby("lea_state_name")[["enrollment", "arrests", "referrals"]]
    .sum()
    .pipe(assign_rates)
    .sort_values(["referral_rate", "arrest_rate"], ascending=False)
)
# Out:
#                       enrollment  arrests  referrals  arrest_rate  \
# lea_state_name
# VIRGINIA                  692817    208.0     1840.0     3.002236
# PENNSYLVANIA              609573     44.0      972.0     0.721817
# NEW HAMPSHIRE              80051     25.0      126.0     3.123009
# ARIZONA                   235820     44.0      328.0     1.865830
# MISSOURI                  400470    225.0      557.0     5.618398
# WASHINGTON                571384    567.0      627.0     9.923274
# DELAWARE                   77398      0.0       79.0     0.000000
# WISCONSIN                 407558     33.0      377.0     0.809701
# FLORIDA                  1634765     35.0     1306.0     0.214098
# SOUTH DAKOTA               70661      5.0       56.0     0.707604
# CALIFORNIA               2353000     33.0     1757.0     0.140246
# WYOMING                    35464      0.0       22.0     0.000000
# NORTH CAROLINA            859144      8.0      458.0     0.093116
# IDAHO                     113053      1.0       59.0     0.088454
# ALASKA                     32839      0.0       17.0     0.000000
# IOWA                      255160     10.0      121.0     0.391911
# KENTUCKY                  340198      2.0      157.0     0.058789
# NORTH DAKOTA               44618      1.0       20.0     0.224125
# VERMONT                    21379      0.0        9.0     0.000000
# MONTANA                    48323      1.0       20.0     0.206941
# TEXAS                    3807668    989.0     1546.0     2.597390
# MARYLAND                  534460    103.0      203.0     1.927179
problem_schools = (
    tot_df.pipe(assign_rates)
    .query(
        "enrollment >= 100 "
        "& referral_rate >= @REFERRAL_RATE_THRESHOLD"
        "& arrest_rate >= @ARREST_RATE_THRESHOLD"
    )
    .sort_values("referral_rate", ascending=False)
)

problem_schools.to_csv("output/schools.csv")

problem_schools
# Out:
#                                                                                                                               enrollment  \
# combokey     sch_name                          lea_name                                     lea_state_name jj sch_status_alt
# 530645002813 Ptarmigan Ridge Elementary School Orting School District                       WASHINGTON     No No                     965
# 290462000054 SCOTT ELEM.                       BELTON 124                                   MISSOURI       No No                     293
# 260769004353 CLK Elementary School             Public Schools of Calumet Laurium & Keweenaw MICHIGAN       No No                     541
# 530645000952 Orting Primary School             Orting School District                       WASHINGTON     No No                     727
# 481662001427 SMITH EL                          DEL VALLE ISD                                TEXAS          No No                    1595
# ...                                                                                                                                  ...
# 130183002314 Lamar Reese School of the Arts    Dougherty County                             GEORGIA        No No                     537
# 510324000381 Barack Obama Elementary           RICHMOND CITY PBLC SCHS                      VIRGINIA       No No                     359
# 550960002342 Zablocki Elementary               Milwaukee School District                    WISCONSIN      No No                     719
# 120009000060 OSCAR PATTERSON ELEMENTARY MAGNET BAY                                          FLORIDA        No No                     361
# 480744002241 THOMAS EL                         ABILENE ISD                                  TEXAS          No No                     566
#
#                                                                                                                               max_grade  \
# combokey     sch_name                          lea_name                                     lea_state_name jj sch_status_alt
# 530645002813 Ptarmigan Ridge Elementary School Orting School District                       WASHINGTON     No No                    5.0
# 290462000054 SCOTT ELEM.                       BELTON 124                                   MISSOURI       No No                    4.0
# 260769004353 CLK Elementary School             Public Schools of Calumet Laurium & Keweenaw MICHIGAN       No No                    5.0
# 530645000952 Orting Primary School             Orting School District                       WASHINGTON     No No                    3.0
# 481662001427 SMITH EL                          DEL VALLE ISD                                TEXAS          No No                    5.0
# ...                                                                                                                                 ...
# 130183002314 Lamar Reese School of the Arts    Dougherty County                             GEORGIA        No No                    5.0
# 510324000381 Barack Obama Elementary           RICHMOND CITY PBLC SCHS                      VIRGINIA       No No                    5.0
# 550960002342 Zablocki Elementary               Milwaukee School District                    WISCONSIN      No No                    5.0
# 120009000060 OSCAR PATTERSON ELEMENTARY MAGNET BAY                                          FLORIDA        No No                    5.0
# 480744002241 THOMAS EL                         ABILENE ISD                                  TEXAS          No No                    5.0
#
#                                                                                                                               arrests  \
# combokey     sch_name                          lea_name                                     lea_state_name jj sch_status_alt
# 530645002813 Ptarmigan Ridge Elementary School Orting School District                       WASHINGTON     No No                484.0
# 290462000054 SCOTT ELEM.                       BELTON 124                                   MISSOURI       No No                 60.0
# 260769004353 CLK Elementary School             Public Schools of Calumet Laurium & Keweenaw MICHIGAN       No No                 67.0
# 530645000952 Orting Primary School             Orting School District                       WASHINGTON     No No                 82.0
# 481662001427 SMITH EL                          DEL VALLE ISD                                TEXAS          No No                177.0
# ...                                                                                                                               ...
# 130183002314 Lamar Reese School of the Arts    Dougherty County                             GEORGIA        No No                  2.0
# 510324000381 Barack Obama Elementary           RICHMOND CITY PBLC SCHS                      VIRGINIA       No No                  2.0
# 550960002342 Zablocki Elementary               Milwaukee School District                    WISCONSIN      No No                  2.0
# 120009000060 OSCAR PATTERSON ELEMENTARY MAGNET BAY                                          FLORIDA        No No                  2.0
