# %% [markdown]
# # Identifying schools that have inaccurate data

# %% [markdown]
# Many schools in this data contain inaccurate values for disipline data due to data entry errors. This notebook documents the various data entry issues with the data. All rows printed in this notebook are removed in `clean/src/clean_crdc_data.py`

# %%
import pandas as pd
import constants

# %% [markdown]
# This input file was copied from the output of the `clean` task without calling the function `drop_data_entry_errors`

# %%
df = pd.read_csv("input/crdc-referrals-arrests-cleaned.csv", low_memory=False)

# %%
df.groupby("year").COMBOKEY.nunique()
# Out:
# year
# 2013    95507
# 2015    29383
# 2017    97632
# Name: COMBOKEY, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['COMBOKEY',
#  'LEA_STATE',
#  'LEAID',
#  'LEA_NAME',
#  'SCHID',
#  'SCH_NAME',
#  'JJ',
#  'SCH_STATUS_ALT',
#  'SCH_ENR_HI_M',
#  'SCH_ENR_HI_F',
#  'SCH_ENR_AM_M',
#  'SCH_ENR_AM_F',
#  'SCH_ENR_AS_M',
#  'SCH_ENR_AS_F',
#  'SCH_ENR_HP_M',
#  'SCH_ENR_HP_F',
#  'SCH_ENR_BL_M',
#  'SCH_ENR_BL_F',
#  'SCH_ENR_WH_M',
#  'SCH_ENR_WH_F',
#  'SCH_ENR_TR_M',
#  'SCH_ENR_TR_F',
#  'TOT_ENR_M',
#  'TOT_ENR_F',
#  'SCH_IDEAENR_HI_M',
#  'SCH_IDEAENR_HI_F',
#  'SCH_IDEAENR_AM_M',
#  'SCH_IDEAENR_AM_F',
#  'SCH_IDEAENR_AS_M',
#  'SCH_IDEAENR_AS_F',
#  'SCH_IDEAENR_HP_M',
#  'SCH_IDEAENR_HP_F',
#  'SCH_IDEAENR_BL_M',
#  'SCH_IDEAENR_BL_F',
#  'SCH_IDEAENR_WH_M',
#  'SCH_IDEAENR_WH_F',
#  'SCH_IDEAENR_TR_M',
#  'SCH_IDEAENR_TR_F',
#  'TOT_IDEAENR_M',
#  'TOT_IDEAENR_F',
#  'SCH_DISCWODIS_REF_HI_M',
#  'SCH_DISCWODIS_REF_HI_F',
#  'SCH_DISCWODIS_REF_AM_M',
#  'SCH_DISCWODIS_REF_AM_F',
#  'SCH_DISCWODIS_REF_AS_M',
#  'SCH_DISCWODIS_REF_AS_F',
#  'SCH_DISCWODIS_REF_HP_M',
#  'SCH_DISCWODIS_REF_HP_F',
#  'SCH_DISCWODIS_REF_BL_M',
#  'SCH_DISCWODIS_REF_BL_F',
#  'SCH_DISCWODIS_REF_WH_M',
#  'SCH_DISCWODIS_REF_WH_F',
#  'SCH_DISCWODIS_REF_TR_M',
#  'SCH_DISCWODIS_REF_TR_F',
#  'TOT_DISCWODIS_REF_M',
#  'TOT_DISCWODIS_REF_F',
#  'SCH_DISCWDIS_REF_IDEA_HI_M',
#  'SCH_DISCWDIS_REF_IDEA_HI_F',
#  'SCH_DISCWDIS_REF_IDEA_AM_M',
#  'SCH_DISCWDIS_REF_IDEA_AM_F',
#  'SCH_DISCWDIS_REF_IDEA_AS_M',
#  'SCH_DISCWDIS_REF_IDEA_AS_F',
#  'SCH_DISCWDIS_REF_IDEA_HP_M',
#  'SCH_DISCWDIS_REF_IDEA_HP_F',
#  'SCH_DISCWDIS_REF_IDEA_BL_M',
#  'SCH_DISCWDIS_REF_IDEA_BL_F',
#  'SCH_DISCWDIS_REF_IDEA_WH_M',
#  'SCH_DISCWDIS_REF_IDEA_WH_F',
#  'SCH_DISCWDIS_REF_IDEA_TR_M',
#  'SCH_DISCWDIS_REF_IDEA_TR_F',
#  'TOT_DISCWDIS_REF_IDEA_M',
#  'TOT_DISCWDIS_REF_IDEA_F',
#  'SCH_DISCWODIS_ARR_HI_M',
#  'SCH_DISCWODIS_ARR_HI_F',
#  'SCH_DISCWODIS_ARR_AM_M',
#  'SCH_DISCWODIS_ARR_AM_F',
#  'SCH_DISCWODIS_ARR_AS_M',
#  'SCH_DISCWODIS_ARR_AS_F',
#  'SCH_DISCWODIS_ARR_HP_M',
#  'SCH_DISCWODIS_ARR_HP_F',
#  'SCH_DISCWODIS_ARR_BL_M',
#  'SCH_DISCWODIS_ARR_BL_F',
#  'SCH_DISCWODIS_ARR_WH_M',
#  'SCH_DISCWODIS_ARR_WH_F',
#  'SCH_DISCWODIS_ARR_TR_M',
#  'SCH_DISCWODIS_ARR_TR_F',
#  'TOT_DISCWODIS_ARR_M',
#  'TOT_DISCWODIS_ARR_F',
#  'SCH_DISCWDIS_ARR_IDEA_HI_M',
#  'SCH_DISCWDIS_ARR_IDEA_HI_F',
#  'SCH_DISCWDIS_ARR_IDEA_AM_M',
#  'SCH_DISCWDIS_ARR_IDEA_AM_F',
#  'SCH_DISCWDIS_ARR_IDEA_AS_M',
#  'SCH_DISCWDIS_ARR_IDEA_AS_F',
#  'SCH_DISCWDIS_ARR_IDEA_HP_M',
#  'SCH_DISCWDIS_ARR_IDEA_HP_F',
#  'SCH_DISCWDIS_ARR_IDEA_BL_M',
#  'SCH_DISCWDIS_ARR_IDEA_BL_F',
#  'SCH_DISCWDIS_ARR_IDEA_WH_M',
#  'SCH_DISCWDIS_ARR_IDEA_WH_F',
#  'SCH_DISCWDIS_ARR_IDEA_TR_M',
#  'SCH_DISCWDIS_ARR_IDEA_TR_F',
#  'TOT_DISCWDIS_ARR_IDEA_M',
#  'TOT_DISCWDIS_ARR_IDEA_F',
#  'max_grade',
#  'year']

# %% [markdown]
# ## Arrest or enrollment rates over 100%
# Per the CRDC documentation, arrest and referral totals are supposed to represent the number of unique students who were referred or arrested. In this data, however, some schools have arrest and referral totals greater than the size of their total enrollment.

# %%
df.query("year == 2015")[["COMBOKEY","LEAID", "SCHID", "SCH_NAME"]]
# Out:
#               COMBOKEY    LEAID  SCHID  \
# 95507      20018000075   200180     75
# 95508      20018000064   200180     64
# 95509      20018000057   200180     57
# 95510      20018000729   200180    729
# 95511      20018000120   200180    120
# ...                ...      ...    ...
# 124885  268036000000.0  2680360   1830
# 124886    24SOP0299996  24SOP02  99996
# 124887    25SOP0199994  25SOP01  99994
# 124888    25SOP0199995  25SOP01  99995
# 124889    25SOP0199989  25SOP01  99989
#
#                                         SCH_NAME
# 95507                           East High School
# 95508                        Clark Middle School
# 95509                       Bartlett High School
# 95510           Nicholas J. Begich Middle School
# 95511                           West High School
# ...                                          ...
# 124885  Dickinson Iron Early Childhood Education
# 124886          J. DEWEESE CARTER YOUTH FACILITY
# 124887                         Goss II Treatment
# 124888                          Goss I Treatment
# 124889                         New River Academy
#
# [29383 rows x 4 columns]

# %%
df.query("total_arrests > total_enrollment | total_referrals > total_enrollment")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/scope.py:198, in Scope.resolve(self, key, is_local)
#     197 if self.has_resolvers:
# --> 198     return self.resolvers[key]
#     200 # if we're here that means that we have no locals and we also have
#     201 # no resolvers
#
# File /usr/local/lib/python3.10/collections/__init__.py:986, in ChainMap.__getitem__(self, key)
#     985         pass
# --> 986 return self.__missing__(key)
#
# File /usr/local/lib/python3.10/collections/__init__.py:978, in ChainMap.__missing__(self, key)
#     977 def __missing__(self, key):
# --> 978     raise KeyError(key)
#
# KeyError: 'total_arrests'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/scope.py:209, in Scope.resolve(self, key, is_local)
#     205 try:
#     206     # last ditch effort we look in temporaries
#     207     # these are created when parsing indexing expressions
#     208     # e.g., df[df > 0]
# --> 209     return self.temps[key]
#     210 except KeyError as err:
#
# KeyError: 'total_arrests'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 df.query("total_arrests > total_enrollment | total_referrals > total_enrollment")
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/frame.py:4464, in DataFrame.query(self, expr, inplace, **kwargs)
#    4462 kwargs["level"] = kwargs.pop("level", 0) + 2
#    4463 kwargs["target"] = None
# -> 4464 res = self.eval(expr, **kwargs)
#    4466 try:
#    4467     result = self.loc[res]
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/frame.py:4602, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4599     kwargs["target"] = self
#    4600 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4602 return _eval(expr, inplace=inplace, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/eval.py:354, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     345 # get our (possibly passed-in) scope
#     346 env = ensure_scope(
#     347     level + 1,
#     348     global_dict=global_dict,
#    (...)
#     351     target=target,
#     352 )
# --> 354 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     356 # construct the engine and evaluate the parsed expression
#     357 eng = ENGINES[engine]
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:813, in Expr.__init__(self, expr, engine, parser, env, level)
#     811 self.parser = parser
#     812 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 813 self.terms = self.parse()
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:832, in Expr.parse(self)
#     828 def parse(self):
#     829     """
#     830     Parse an expression.
#     831     """
# --> 832     return self._visitor.visit(self.expr)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:750, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     747     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     749 operands = node.values
# --> 750 return reduce(visitor, operands)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:743, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     742 def visitor(x, y):
# --> 743     lhs = self._try_visit_binop(x)
#     744     rhs = self._try_visit_binop(y)
#     746     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:739, in BaseExprVisitor._try_visit_binop(self, bop)
#     737 if isinstance(bop, (Op, Term)):
#     738     return bop
# --> 739 return self.visit(bop)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:723, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     721     op = self.translate_In(ops[0])
#     722     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 723     return self.visit(binop)
#     725 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     726 left = node.left
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:536, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 def visit_BinOp(self, node, **kwargs):
# --> 536     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     537     left, right = self._maybe_downcast_constants(left, right)
#     538     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:456, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     454 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     455     if left is None:
# --> 456         left = self.visit(node.left, side="left")
#     457     if right is None:
#     458         right = self.visit(node.right, side="right")
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/expr.py:549, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     548 def visit_Name(self, node, **kwargs):
# --> 549     return self.term_type(node.id, self.env, **kwargs)
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/ops.py:85, in Term.__init__(self, name, env, side, encoding)
#      83 tname = str(name)
#      84 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 85 self._value = self._resolve_name()
#      86 self.encoding = encoding
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/ops.py:109, in Term._resolve_name(self)
#     104 if local_name in self.env.scope and isinstance(
#     105     self.env.scope[local_name], type
#     106 ):
#     107     is_local = False
# --> 109 res = self.env.resolve(local_name, is_local=is_local)
#     110 self.update(res)
#     112 if hasattr(res, "ndim") and res.ndim > 2:
#
# File /workspaces/crdc-le-referral-data/venv/lib/python3.10/site-packages/pandas/core/computation/scope.py:211, in Scope.resolve(self, key, is_local)
#     209     return self.temps[key]
#     210 except KeyError as err:
# --> 211     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'total_arrests' is not defined

# %% [markdown]
# ## More arrests than referrals
# Per the CRDC documentation, all arrests are to be counted as referrals, but not all referrals are arrests, therefore the number of arrests should never be greater than the number of referrals.

# %%
df.query("total_arrests > total_referrals")
# Out:
#             COMBOKEY LEA_STATE    LEAID                              LEA_NAME  \
# 85      320048000545        NV  3200480         WASHOE COUNTY SCHOOL DISTRICT
# 144     550852000925        WI  5508520  MADISON METROPOLITAN SCHOOL DISTRICT
# 154     170993003505        IL  1709930                CITY OF CHICAGO SD 299
# 171     180363000548        IN  1803630          FORT WAYNE COMMUNITY SCHOOLS
# 172     180363000550        IN  1803630          FORT WAYNE COMMUNITY SCHOOLS
# ...              ...       ...      ...                                   ...
# 216694  180192000249        IN  1801920     Clarksville Community School Corp
# 216697  180192000248        IN  1801920     Clarksville Community School Corp
# 216870  180951001555        IN  1809510            Richmond Community Schools
# 217026  181110001798        IN  1811100                  M S D Steuben County
# 217476  192739001597        IA  1927390       Storm Lake Comm School District
#
#         SCHID                        SCH_NAME  JJ SCH_STATUS_ALT  \
# 85        545     SPANISH SPRINGS HIGH SCHOOL  No             No
# 144       925                       EAST HIGH  No             No
# 154      3505   CHICAGO INTERNATIONAL CHARTER  No             No
# 171       548             MIAMI MIDDLE SCHOOL  No             No
# 172       550          NORTH SIDE HIGH SCHOOL  No             No
# ...       ...                             ...  ..            ...
# 216694    249  Clarksville Senior High School  No             No
# 216697    248       Clarksville Middle School  No             No
# 216870   1555      Dennis Intermediate School  No             No
# 217026   1798            Angola Middle School  No             No
# 217476   1597        East Early Childhood Ctr  No             No
#
#         SCH_ENR_HI_M  SCH_ENR_HI_F  ...  total_arrests_hp  total_referrals_hp  \
# 85             335.0         311.0  ...               0.0                 0.0
# 144            122.0         122.0  ...               0.0                 0.0
# 154           1172.0        1121.0  ...               0.0                 0.0
# 171             83.0          95.0  ...               0.0                 0.0
# 172             86.0          92.0  ...               0.0                 0.0
# ...              ...           ...  ...               ...                 ...
# 216694          23.0          18.0  ...               0.0                 0.0
# 216697          23.0          18.0  ...               0.0                 0.0
# 216870          35.0          31.0  ...               0.0                 0.0
# 217026          46.0          29.0  ...               0.0                 0.0
# 217476          41.0          38.0  ...               1.0                 0.0
#
#         total_arrests_tr  total_referrals_tr  total_arrests_idea  \
# 85                   4.0                 2.0                17.0
# 144                  4.0                 0.0                 8.0
# 154                  0.0                 0.0                 0.0
# 171                  0.0                 0.0                 4.0
# 172                  0.0                 0.0                 4.0
# ...                  ...                 ...                 ...
# 216694               0.0                 0.0                 0.0
# 216697               0.0                 0.0                 0.0
# 216870               3.0                 4.0                 3.0
# 217026               0.0                 0.0                 0.0
# 217476               0.0                 0.0                 0.0
#
#         total_arrests_nondis  total_referrals_idea  total_referrals_nondis  \
# 85                      50.0                   2.0                     4.0
# 144                      0.0                   2.0                     2.0
# 154                      8.0                   0.0                     5.0
# 171                      2.0                   0.0                     0.0
# 172                      2.0                   2.0                     2.0
# ...                      ...                   ...                     ...
# 216694                   3.0                   0.0                     0.0
# 216697                   3.0                   0.0                     0.0
# 216870                  11.0                   2.0                    11.0
# 217026                  12.0                   0.0                    10.0
# 217476                   5.0                   0.0                     0.0
#
#         total_enrollment_idea  total_enrollment_nondis
# 85                      263.0                   2296.0
# 144                     323.0                   1613.0
# 154                    1211.0                   8563.0
# 171                     148.0                    777.0
# 172                     283.0                   1667.0
# ...                       ...                      ...
# 216694                   85.0                    424.0
# 216697                   85.0                    424.0
# 216870                  133.0                    649.0
# 217026                  113.0                    660.0
# 217476                   33.0                    142.0
#
# [2285 rows x 130 columns]

# %% [markdown]
# ## Schools with very high totals and near-identical arrest and referral rates
# After reaching out to Del Valle ISD outside Austin, TX, we were told their data was incorrect and that the person who did the data entry for the distict misunderstood the definitions in the discipline section. All of their schools reported extremely high arrest and referral totals, and had arrest totals that were equal or nearly equal to their referral totals. It's clear that there are several other districts that made the same error -- all have significantly high arrest totals that are identical to their referral totals

# %%
df = df.assign(
    grade_category=lambda df: df.apply(
        lambda row: "high school"
        if row.max_grade in range(10, 13)
        else "middle school"
        if row.max_grade in range(7, 10)
        else "elementary school"
        if row.max_grade in range(1, 7)
        else "other",
        axis=1,
    )
)

threshold_df = (
    df.groupby(["grade_category", "year"])
    .total_referrals_arrests.quantile(0.999)
    .to_frame("threshold")
)

threshold_df
# Out:
#                         threshold
# grade_category    year
# elementary school 2013     58.730
#                   2015     35.522
#                   2017     29.260
# high school       2013    221.608
#                   2015    236.100
#                   2017    193.498
# middle school     2013    193.800
#                   2015    105.514
#                   2017    137.282
# other             2013     44.737
#                   2015      7.772
#                   2017      6.806

# %%
close_vals = list(range(0, 3))
df.merge(threshold_df, left_on=["grade_category", "year"], right_index=True).query(
    "total_referrals_arrests > threshold & abs(total_arrests - total_referrals) in @close_vals"
)
# Out:
#               COMBOKEY LEA_STATE    LEAID  \
# 231       271242000610        MN  2712420
# 14314     290462002517        MO  2904620
# 70510     291376002659        MO  2913760
# 3614      271242000611        MN  2712420
# 74157     251050001684        MA  2510500
